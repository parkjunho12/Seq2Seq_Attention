# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %%
from tensorflow.keras import layers

# %%
class MyModel(tf.keras.Model):
    def __init__(self, num_classes=10):
        super(MyModel, self).__init__(name='my_model')
        self.num_classes = num_classes
        self.dense_1 = layers.Dense(32, activation='relu')
        self.dense_2 = layers.Dense(num_classes, activation='sigmoid')
        
    def call(self, inputs):
        x = self.dense_1(inputs)
        return self.dense_2(x)

# %%
model = MyModel(num_classes=10)

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(0.001),
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
import numpy as np
data = np.random.random((1000, 32))

# %%
labels = np.random.random((1000, 10))

# %%
model.fit(data, labels, batch_size=32, epochs=5)
model.save_weights('./weights/my_model')
model.load_weights('./weights/my_model')
# Out:
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 106us/sample - loss: 11.5013 - accuracy: 0.1240
# Epoch 2/5
# 1000/1000 [==============================] - 0s 90us/sample - loss: 11.5003 - accuracy: 0.1310
# Epoch 3/5
# 1000/1000 [==============================] - 0s 90us/sample - loss: 11.4991 - accuracy: 0.1320
# Epoch 4/5
# 1000/1000 [==============================] - 0s 88us/sample - loss: 11.4978 - accuracy: 0.1360
# Epoch 5/5
# 1000/1000 [==============================] - 0s 90us/sample - loss: 11.4971 - accuracy: 0.1290

# %%
import json

# %%
model.summary()
# Out:
# Model: "my_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  1056
# _________________________________________________________________
# dense_1 (Dense)              multiple                  330
# =================================================================
# Total params: 1,386
# Trainable params: 1,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.evaluate(data, labels)
# Out:
# 1000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [11.49455955505371, 0.135]

# %%
pre = np.random.random((1,32))
print(pre)

score = model.predict(pre, batch_size=32)
print(score.shape)
# Out:
# [[0.9732716  0.03492085 0.63301643 0.01296984 0.60887643 0.73372742
#   0.0364175  0.39043143 0.07011267 0.26723601 0.84113175 0.63442261
#   0.29843814 0.79328747 0.46988489 0.14980375 0.74951097 0.44629299
#   0.66752911 0.81336376 0.41740218 0.65091696 0.69087697 0.53054549
#   0.39120108 0.61178988 0.74918924 0.63685092 0.38006999 0.90349701
#   0.98149678 0.71346733]]
# (1, 10)

# %%
print(score)
# Out:
# [[0.5725835  0.55454254 0.49521464 0.54804474 0.52760255 0.544167
#   0.5011006  0.479653   0.5649704  0.48873726]]
